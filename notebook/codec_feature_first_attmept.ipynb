# %%
import sys
sys.path.append('..')
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from video_codec_cnn.extract_cnn_features import extract_features
# Out:
# Using TensorFlow backend.

# %%
dataset_root = '/home/nbonettini/MFC18_EvalPart1_Video_Ver1/'

# %%
df = pd.read_csv('/nas/public/dataset/medifor/MFC18_EvalPart1_Video_Ver1-Reference/reference/manipulation-video/MFC18_EvalPart1-manipulation-video-ref.csv', sep='|')

# %%
df
# Out:
#             TaskID                       ProbeFileID  \
# 0     manipulation  001c934acb38a59cb28b680b79485dcd
# 1     manipulation  0091ab5777b1471fd91f064e4a60a595
# 2     manipulation  0129177928b30b3e69f5d4e423096443
# 3     manipulation  014626484bcedfa95d97be1cbf18a6c4
# 4     manipulation  01a1abdac4b4a7d06e1b49c4bc6eab59
# 5     manipulation  01b24a3e3dbc4db3f2ae041a71706672
# 6     manipulation  01d1021c3452df3c3bdcbe950f7e632e
# 7     manipulation  0213d4acd6353cdf2e3b0d8a657a6442
# 8     manipulation  022baa12715fe12cc78d6fbddfab9e7c
# 9     manipulation  02652f2f474dc52a9e8d48b04ebebd35
# 10    manipulation  02735e302e099778de8ec1e2c123e64b
# 11    manipulation  02fe8557d7997f68e711a981c90d27b1
# 12    manipulation  03084355e04bf5fc073dbcaa7b352829
# 13    manipulation  034225d364f1a348d8bb72a028bbe8d5
# 14    manipulation  035aaa3ca255d4039fe0e534694a6959
# 15    manipulation  03680a838f2920cbfc68d2a48a415010
# 16    manipulation  03f2a7dd10b638a785449165448a6056
# 17    manipulation  044c77ec5799b9904f545a8d1615f237
# 18    manipulation  04e6d3b69770c1403d426999f2a50e2f
# 19    manipulation  04ef4681bfe12d30bfc8885cfa3b66ba
# 20    manipulation  0575dc5bcee1e41a27d4a7a1b9864faa
# 21    manipulation  059e3be745baa59bf79a63e03abaeec3
# 22    manipulation  05a343d33f07b8b2efd12bc786432133
# 23    manipulation  05f77d56af0c00450650d31b00d6e352
# 24    manipulation  064c72af88355d51a1797f8b7ac0d498
# 25    manipulation  0666f383b4a54fa2ec5ff61543d9e2aa
# 26    manipulation  0679b7e6a1688ff412e18bdebe246442
# 27    manipulation  0680977590133572e545af6380d74327
# 28    manipulation  0684748afa7c18f63cd95c4c363faaf2
# 29    manipulation  06b8905166bda0f9f30b183d069cc17f
# ...            ...                               ...
# 1006  manipulation  f8d2ed5d34124e8ad3bd4d4a1d108184
# 1007  manipulation  f90377ad9ef0db67474d1eda67fd5a2c
# 1008  manipulation  f921e98fdf7e1e358e2c31cc16cc4ef4
# 1009  manipulation  fae078dd963c3c8c26f5a9eb8b06eb3d
# 1010  manipulation  fb1e4f00af2116fe2b10f5c3d6223f97
# 1011  manipulation  fb1fcb64ae3666e50e92b4bf09933854
# 1012  manipulation  fb224eadddf5f708f52c6d50005d0b74
# 1013  manipulation  fb44a736cf16cf758fd9d3d5dc79b6d5
# 1014  manipulation  fb55181679e50b586a5e81f645eaad4a
# 1015  manipulation  fb7d68d138740670ed9f388ce1c7a341
# 1016  manipulation  fc1c6a3d2d4da87d9dc5dbd9b0cef578
# 1017  manipulation  fc4c03a3586077c3ffe14257f60a7584
# 1018  manipulation  fc6ff387bfea183a5ba9f0a95ad40c95
# 1019  manipulation  fc70838b235ec817564d80da5642ea73
# 1020  manipulation  fd59c4e46e2bd4e42d08f785bef2c3b1
# 1021  manipulation  fd6315a24d60804214207729344a045f
# 1022  manipulation  fd87f9315c7a6e10dbb3b52e07c4aada
# 1023  manipulation  fda476ada8b5820efd07ea2c40c4736e
# 1024  manipulation  fdadeecd2bf99bc2329ca2f64467dcab
# 1025  manipulation  fdfa9436a0f9a6e6adff20a03fbc7e5a
# 1026  manipulation  fe26257f88a52f481f78479069203645
# 1027  manipulation  fe47fcc7349d84850c9b1d9aa8f30893
# 1028  manipulation  fe4e9f2aae18c761c33752f4d035ca53
# 1029  manipulation  fe513baaf0cafc935b7b3774aed85a27
# 1030  manipulation  fec6dc4d4ee22d98cffb8c42937e564f
# 1031  manipulation  fededcd4aab1ce9b9966108e99ba78cf
# 1032  manipulation  fee2e815ef5a5c2426a3b450f0238475
# 1033  manipulation  ff1b23ecc5b1b329e7a0f7d3bf44f22d
# 1034  manipulation  ff6da67e19a1d9572471e13ca617f147
# 1035  manipulation  ffab545957c6f9d66a4eeeafdc218928
#
#                                    ProbeFileName IsTarget  ProbeMaskFileName  \
# 0     probe/001c934acb38a59cb28b680b79485dcd.mp4        N                NaN
# 1     probe/0091ab5777b1471fd91f064e4a60a595.mp4        N                NaN
# 2     probe/0129177928b30b3e69f5d4e423096443.mp4        N                NaN
# 3     probe/014626484bcedfa95d97be1cbf18a6c4.mov        N                NaN
# 4     probe/01a1abdac4b4a7d06e1b49c4bc6eab59.mp4        N                NaN
# 5     probe/01b24a3e3dbc4db3f2ae041a71706672.mp4        N                NaN
# 6     probe/01d1021c3452df3c3bdcbe950f7e632e.mp4        Y                NaN
# 7     probe/0213d4acd6353cdf2e3b0d8a657a6442.mp4        N                NaN
# 8     probe/022baa12715fe12cc78d6fbddfab9e7c.3gp        Y                NaN
# 9     probe/02652f2f474dc52a9e8d48b04ebebd35.mov        N                NaN
# 10    probe/02735e302e099778de8ec1e2c123e64b.mov        N                NaN
# 11    probe/02fe8557d7997f68e711a981c90d27b1.mp4        Y                NaN
# 12    probe/03084355e04bf5fc073dbcaa7b352829.mp4        N                NaN
# 13    probe/034225d364f1a348d8bb72a028bbe8d5.mov        N                NaN
# 14    probe/035aaa3ca255d4039fe0e534694a6959.mp4        Y                NaN
# 15    probe/03680a838f2920cbfc68d2a48a415010.mp4        N                NaN
# 16    probe/03f2a7dd10b638a785449165448a6056.mov        N                NaN
# 17    probe/044c77ec5799b9904f545a8d1615f237.mp4        N                NaN
# 18    probe/04e6d3b69770c1403d426999f2a50e2f.mp4        N                NaN
# 19    probe/04ef4681bfe12d30bfc8885cfa3b66ba.mp4        N                NaN
# 20    probe/0575dc5bcee1e41a27d4a7a1b9864faa.mp4        N                NaN
# 21    probe/059e3be745baa59bf79a63e03abaeec3.mp4        N                NaN
# 22    probe/05a343d33f07b8b2efd12bc786432133.avi        N                NaN
# 23    probe/05f77d56af0c00450650d31b00d6e352.mp4        N                NaN
# 24    probe/064c72af88355d51a1797f8b7ac0d498.mov        N                NaN
# 25    probe/0666f383b4a54fa2ec5ff61543d9e2aa.mov        Y                NaN
# 26    probe/0679b7e6a1688ff412e18bdebe246442.mp4        Y                NaN
# 27    probe/0680977590133572e545af6380d74327.mp4        Y                NaN
# 28    probe/0684748afa7c18f63cd95c4c363faaf2.mp4        Y                NaN
# 29    probe/06b8905166bda0f9f30b183d069cc17f.mp4        N                NaN
# ...                                          ...      ...                ...
# 1006  probe/f8d2ed5d34124e8ad3bd4d4a1d108184.mp4        Y                NaN
# 1007  probe/f90377ad9ef0db67474d1eda67fd5a2c.mp4        Y                NaN
# 1008  probe/f921e98fdf7e1e358e2c31cc16cc4ef4.mov        N                NaN
# 1009  probe/fae078dd963c3c8c26f5a9eb8b06eb3d.mp4        N                NaN
# 1010  probe/fb1e4f00af2116fe2b10f5c3d6223f97.mp4        N                NaN
# 1011  probe/fb1fcb64ae3666e50e92b4bf09933854.mp4        Y                NaN
# 1012  probe/fb224eadddf5f708f52c6d50005d0b74.mp4        N                NaN
# 1013  probe/fb44a736cf16cf758fd9d3d5dc79b6d5.mp4        N                NaN
# 1014  probe/fb55181679e50b586a5e81f645eaad4a.mov        Y                NaN
# 1015  probe/fb7d68d138740670ed9f388ce1c7a341.mp4        Y                NaN
# 1016  probe/fc1c6a3d2d4da87d9dc5dbd9b0cef578.mp4        N                NaN
# 1017  probe/fc4c03a3586077c3ffe14257f60a7584.mov        N                NaN
# 1018  probe/fc6ff387bfea183a5ba9f0a95ad40c95.mp4        N                NaN
# 1019  probe/fc70838b235ec817564d80da5642ea73.mp4        N                NaN
# 1020  probe/fd59c4e46e2bd4e42d08f785bef2c3b1.mp4        N                NaN
# 1021  probe/fd6315a24d60804214207729344a045f.mp4        N                NaN
# 1022  probe/fd87f9315c7a6e10dbb3b52e07c4aada.mov        N                NaN
# 1023  probe/fda476ada8b5820efd07ea2c40c4736e.mp4        N                NaN
# 1024  probe/fdadeecd2bf99bc2329ca2f64467dcab.mp4        Y                NaN
# 1025  probe/fdfa9436a0f9a6e6adff20a03fbc7e5a.mp4        N                NaN
# 1026  probe/fe26257f88a52f481f78479069203645.mp4        N                NaN
# 1027  probe/fe47fcc7349d84850c9b1d9aa8f30893.mp4        N                NaN
# 1028  probe/fe4e9f2aae18c761c33752f4d035ca53.mp4        N                NaN
# 1029  probe/fe513baaf0cafc935b7b3774aed85a27.mp4        Y                NaN
# 1030  probe/fec6dc4d4ee22d98cffb8c42937e564f.mp4        N                NaN
# 1031  probe/fededcd4aab1ce9b9966108e99ba78cf.mp4        Y                NaN
# 1032  probe/fee2e815ef5a5c2426a3b450f0238475.mts        N                NaN
# 1033  probe/ff1b23ecc5b1b329e7a0f7d3bf44f22d.mp4        N                NaN
# 1034  probe/ff6da67e19a1d9572471e13ca617f147.mp4        N                NaN
# 1035  probe/ffab545957c6f9d66a4eeeafdc218928.mp4        Y                NaN
#
#       ProbeBitPlaneMaskFileName                  ProbeBrowserFileName  \
# 0                           NaN  001c934acb38a59cb28b680b79485dcd.mp4
# 1                           NaN  0091ab5777b1471fd91f064e4a60a595.mp4
# 2                           NaN  0129177928b30b3e69f5d4e423096443.mp4
# 3                           NaN  014626484bcedfa95d97be1cbf18a6c4.mov
# 4                           NaN  01a1abdac4b4a7d06e1b49c4bc6eab59.mp4
# 5                           NaN  01b24a3e3dbc4db3f2ae041a71706672.mp4
# 6                           NaN  01d1021c3452df3c3bdcbe950f7e632e.mp4
# 7                           NaN  0213d4acd6353cdf2e3b0d8a657a6442.mp4
# 8                           NaN  022baa12715fe12cc78d6fbddfab9e7c.3gp
# 9                           NaN  02652f2f474dc52a9e8d48b04ebebd35.mov
# 10                          NaN  02735e302e099778de8ec1e2c123e64b.mov
# 11                          NaN  02fe8557d7997f68e711a981c90d27b1.mp4
# 12                          NaN  03084355e04bf5fc073dbcaa7b352829.mp4
# 13                          NaN  034225d364f1a348d8bb72a028bbe8d5.mov
# 14                          NaN  035aaa3ca255d4039fe0e534694a6959.mp4
# 15                          NaN  03680a838f2920cbfc68d2a48a415010.mp4
# 16                          NaN  03f2a7dd10b638a785449165448a6056.mov
# 17                          NaN  044c77ec5799b9904f545a8d1615f237.mp4
# 18                          NaN  04e6d3b69770c1403d426999f2a50e2f.mp4
# 19                          NaN  04ef4681bfe12d30bfc8885cfa3b66ba.mp4
# 20                          NaN  0575dc5bcee1e41a27d4a7a1b9864faa.mp4
# 21                          NaN  059e3be745baa59bf79a63e03abaeec3.mp4
# 22                          NaN  05a343d33f07b8b2efd12bc786432133.avi
# 23                          NaN  05f77d56af0c00450650d31b00d6e352.mp4
# 24                          NaN  064c72af88355d51a1797f8b7ac0d498.mov
# 25                          NaN  0666f383b4a54fa2ec5ff61543d9e2aa.mov
# 26                          NaN  0679b7e6a1688ff412e18bdebe246442.mp4
# 27                          NaN  0680977590133572e545af6380d74327.mp4
# 28                          NaN  0684748afa7c18f63cd95c4c363faaf2.mp4
# 29                          NaN  06b8905166bda0f9f30b183d069cc17f.mp4
# ...                         ...                                   ...
# 1006                        NaN  f8d2ed5d34124e8ad3bd4d4a1d108184.mp4
# 1007                        NaN  f90377ad9ef0db67474d1eda67fd5a2c.mp4
# 1008                        NaN  f921e98fdf7e1e358e2c31cc16cc4ef4.mov
# 1009                        NaN  fae078dd963c3c8c26f5a9eb8b06eb3d.mp4
# 1010                        NaN  fb1e4f00af2116fe2b10f5c3d6223f97.mp4
# 1011                        NaN  fb1fcb64ae3666e50e92b4bf09933854.mp4
# 1012                        NaN  fb224eadddf5f708f52c6d50005d0b74.mp4
# 1013                        NaN  fb44a736cf16cf758fd9d3d5dc79b6d5.mp4
# 1014                        NaN  fb55181679e50b586a5e81f645eaad4a.mov
# 1015                        NaN  fb7d68d138740670ed9f388ce1c7a341.mp4
# 1016                        NaN  fc1c6a3d2d4da87d9dc5dbd9b0cef578.mp4
# 1017                        NaN  fc4c03a3586077c3ffe14257f60a7584.mov
# 1018                        NaN  fc6ff387bfea183a5ba9f0a95ad40c95.mp4
# 1019                        NaN  fc70838b235ec817564d80da5642ea73.mp4
# 1020                        NaN  fd59c4e46e2bd4e42d08f785bef2c3b1.mp4
# 1021                        NaN  fd6315a24d60804214207729344a045f.mp4
# 1022                        NaN  fd87f9315c7a6e10dbb3b52e07c4aada.mov
# 1023                        NaN  fda476ada8b5820efd07ea2c40c4736e.mp4
# 1024                        NaN  fdadeecd2bf99bc2329ca2f64467dcab.mp4
# 1025                        NaN  fdfa9436a0f9a6e6adff20a03fbc7e5a.mp4
# 1026                        NaN  fe26257f88a52f481f78479069203645.mp4
# 1027                        NaN  fe47fcc7349d84850c9b1d9aa8f30893.mp4
# 1028                        NaN  fe4e9f2aae18c761c33752f4d035ca53.mp4
# 1029                        NaN  fe513baaf0cafc935b7b3774aed85a27.mp4
# 1030                        NaN  fec6dc4d4ee22d98cffb8c42937e564f.mp4
# 1031                        NaN  fededcd4aab1ce9b9966108e99ba78cf.mp4
# 1032                        NaN  fee2e815ef5a5c2426a3b450f0238475.mts
# 1033                        NaN  ff1b23ecc5b1b329e7a0f7d3bf44f22d.mp4
# 1034                        NaN  ff6da67e19a1d9572471e13ca617f147.mp4
# 1035                        NaN  ffab545957c6f9d66a4eeeafdc218928.mp4
#
#                                     BaseFileName  \
# 0     world/001c934acb38a59cb28b680b79485dcd.mp4
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6     world/a827f69d3af269c37721e327d2788f0f.mp4
# 7                                            NaN
# 8     world/17708284a6eb1fb7b3cd65ac525dbf3e.mp4
# 9                                            NaN
# 10                                           NaN
# 11    world/3a5cf9d11d47f1c0745d5ed7b42da22a.mp4
# 12                                           NaN
# 13                                           NaN
# 14    world/3141521c819ffd11608bcb929433f4aa.mp4
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19    world/04ef4681bfe12d30bfc8885cfa3b66ba.mp4
# 20    world/0575dc5bcee1e41a27d4a7a1b9864faa.mp4
# 21    world/059e3be745baa59bf79a63e03abaeec3.mp4
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25    world/38b2f61c3eee6d030180c260e165c754.mov
# 26    world/94e53adbf368aab1dec4710de9d203e3.mp4
# 27    world/0575dc5bcee1e41a27d4a7a1b9864faa.mp4
# 28    world/21e35ce8cd98540ef72cdf2a1dd6d64f.mp4
# 29                                           NaN
# ...                                          ...
# 1006  world/0d57c5e84596a8e937be5b6b50c9cac7.mp4
# 1007  world/172864832d46c8f95b625db6d00e2311.mp4
# 1008                                         NaN
# 1009                                         NaN
# 1010                                         NaN
# 1011  world/eb77534b5d09f5c7af95afed00d69fdc.mp4
# 1012                                         NaN
# 1013                                         NaN
# 1014  world/e1662b7f6547109daa5a4e04781c675d.mp4
# 1015  world/ea9c67fa2bdc8a3a720d6d0d423d20b5.mp4
# 1016                                         NaN
# 1017                                         NaN
# 1018  world/fc6ff387bfea183a5ba9f0a95ad40c95.mp4
# 1019                                         NaN
# 1020  world/fd59c4e46e2bd4e42d08f785bef2c3b1.mp4
# 1021                                         NaN
# 1022                                         NaN
# 1023                                         NaN
# 1024  world/0a1f229e64a42c685d347fda749b7fbf.mp4
# 1025                                         NaN
# 1026  world/fe26257f88a52f481f78479069203645.mp4
# 1027                                         NaN
# 1028                                         NaN
# 1029  world/a827f69d3af269c37721e327d2788f0f.mp4
# 1030                                         NaN
# 1031  world/04ef4681bfe12d30bfc8885cfa3b66ba.mp4
# 1032                                         NaN
# 1033                                         NaN
# 1034                                         NaN
# 1035  world/172864832d46c8f95b625db6d00e2311.mp4
#
#                        BaseBrowserFileName                       JournalName  \
# 0     001c934acb38a59cb28b680b79485dcd.mp4  001c934acb38a59cb28b680b79485dcd
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# 5                                      NaN                               NaN
# 6     a827f69d3af269c37721e327d2788f0f.mp4  a827f69d3af269c37721e327d2788f0f
# 7                                      NaN                               NaN
# 8     17708284a6eb1fb7b3cd65ac525dbf3e.mp4  17708284a6eb1fb7b3cd65ac525dbf3e
# 9                                      NaN                               NaN
# 10                                     NaN                               NaN
# 11    3a5cf9d11d47f1c0745d5ed7b42da22a.mp4  3a5cf9d11d47f1c0745d5ed7b42da22a
# 12                                     NaN                               NaN
# 13                                     NaN                               NaN
# 14    3141521c819ffd11608bcb929433f4aa.mp4  3141521c819ffd11608bcb929433f4aa
# 15                                     NaN                               NaN
# 16                                     NaN                               NaN
# 17                                     NaN                               NaN
# 18                                     NaN                               NaN
# 19    04ef4681bfe12d30bfc8885cfa3b66ba.mp4  04ef4681bfe12d30bfc8885cfa3b66ba
# 20    0575dc5bcee1e41a27d4a7a1b9864faa.mp4  0575dc5bcee1e41a27d4a7a1b9864faa
# 21    059e3be745baa59bf79a63e03abaeec3.mp4  059e3be745baa59bf79a63e03abaeec3
# 22                                     NaN                               NaN
# 23                                     NaN                               NaN
# 24                                     NaN                               NaN
# 25    38b2f61c3eee6d030180c260e165c754.mov  38b2f61c3eee6d030180c260e165c754
# 26    94e53adbf368aab1dec4710de9d203e3.mp4  94e53adbf368aab1dec4710de9d203e3
# 27    0575dc5bcee1e41a27d4a7a1b9864faa.mp4  0575dc5bcee1e41a27d4a7a1b9864faa
# 28    21e35ce8cd98540ef72cdf2a1dd6d64f.mp4  21e35ce8cd98540ef72cdf2a1dd6d64f
# 29                                     NaN                               NaN
# ...                                    ...                               ...
# 1006  0d57c5e84596a8e937be5b6b50c9cac7.mp4  0d57c5e84596a8e937be5b6b50c9cac7
# 1007  172864832d46c8f95b625db6d00e2311.mp4  172864832d46c8f95b625db6d00e2311
# 1008                                   NaN                               NaN
# 1009                                   NaN                               NaN
# 1010                                   NaN                               NaN
# 1011  eb77534b5d09f5c7af95afed00d69fdc.mp4  eb77534b5d09f5c7af95afed00d69fdc
# 1012                                   NaN                               NaN
# 1013                                   NaN                               NaN
# 1014  e1662b7f6547109daa5a4e04781c675d.mp4  e1662b7f6547109daa5a4e04781c675d
# 1015  ea9c67fa2bdc8a3a720d6d0d423d20b5.mp4  ea9c67fa2bdc8a3a720d6d0d423d20b5
# 1016                                   NaN                               NaN
# 1017                                   NaN                               NaN
# 1018  fc6ff387bfea183a5ba9f0a95ad40c95.mp4  fc6ff387bfea183a5ba9f0a95ad40c95
# 1019                                   NaN                               NaN
# 1020  fd59c4e46e2bd4e42d08f785bef2c3b1.mp4  fd59c4e46e2bd4e42d08f785bef2c3b1
# 1021                                   NaN                               NaN
# 1022                                   NaN                               NaN
# 1023                                   NaN                               NaN
# 1024  0a1f229e64a42c685d347fda749b7fbf.mp4  0a1f229e64a42c685d347fda749b7fbf
# 1025                                   NaN                               NaN
# 1026  fe26257f88a52f481f78479069203645.mp4  fe26257f88a52f481f78479069203645
# 1027                                   NaN                               NaN
# 1028                                   NaN                               NaN
# 1029  a827f69d3af269c37721e327d2788f0f.mp4  a827f69d3af269c37721e327d2788f0f
# 1030                                   NaN                               NaN
# 1031  04ef4681bfe12d30bfc8885cfa3b66ba.mp4  04ef4681bfe12d30bfc8885cfa3b66ba
# 1032                                   NaN                               NaN
# 1033                                   NaN                               NaN
# 1034                                   NaN                               NaN
# 1035  172864832d46c8f95b625db6d00e2311.mp4  172864832d46c8f95b625db6d00e2311
#
#              ...         ManipulationCategory Natural  \
# 0            ...                           no      no
# 1            ...                          NaN     NaN
# 2            ...                          NaN     NaN
# 3            ...                          NaN     NaN
# 4            ...                          NaN     NaN
# 5            ...                          NaN     NaN
# 6            ...                       5-Unit      no
# 7            ...                          NaN     NaN
# 8            ...                       4-Unit      no
# 9            ...                          NaN     NaN
# 10           ...                          NaN     NaN
# 11           ...                       4-Unit      no
# 12           ...                          NaN     NaN
# 13           ...                          NaN     NaN
# 14           ...                       3-Unit      no
# 15           ...                          NaN     NaN
# 16           ...                          NaN     NaN
# 17           ...                          NaN     NaN
# 18           ...                          NaN     NaN
# 19           ...                           no      no
# 20           ...                           no      no
# 21           ...                           no      no
# 22           ...                          NaN     NaN
# 23           ...                          NaN     NaN
# 24           ...                          NaN     NaN
# 25           ...                       2-Unit      no
# 26           ...                       3-Unit      no
# 27           ...                       4-Unit      no
# 28           ...                       2-Unit      no
# 29           ...                          NaN     NaN
# ...          ...                          ...     ...
# 1006         ...                       3-Unit      no
# 1007         ...                       3-Unit      no
# 1008         ...                          NaN     NaN
# 1009         ...                          NaN     NaN
# 1010         ...                          NaN     NaN
# 1011         ...                       3-Unit      no
# 1012         ...                          NaN     NaN
# 1013         ...                          NaN     NaN
# 1014         ...                       4-Unit      no
# 1015         ...                       2-Unit      no
# 1016         ...                          NaN     NaN
# 1017         ...                          NaN     NaN
# 1018         ...                           no      no
# 1019         ...                          NaN     NaN
# 1020         ...                           no      no
# 1021         ...                          NaN     NaN
# 1022         ...                          NaN     NaN
# 1023         ...                          NaN     NaN
# 1024         ...                       3-Unit      no
# 1025         ...                          NaN     NaN
# 1026         ...                           no      no
# 1027         ...                          NaN     NaN
# 1028         ...                          NaN     NaN
# 1029         ...                       5-Unit      no
# 1030         ...                          NaN     NaN
# 1031         ...                       3-Unit      no
# 1032         ...                          NaN     NaN
# 1033         ...                          NaN     NaN
# 1034         ...                          NaN     NaN
# 1035         ...                       4-Unit      no
#
#       PostprocessStabilization DataEmbeddingSteganography SemanticRestaging  \
# 0                           no                         no                no
# 1                          NaN                        NaN               NaN
# 2                          NaN                        NaN               NaN
# 3                          NaN                        NaN               NaN
# 4                          NaN                        NaN               NaN
# 5                          NaN                        NaN               NaN
# 6                           no                         no               yes
# 7                          NaN                        NaN               NaN
# 8                           no                         no               yes
# 9                          NaN                        NaN               NaN
# 10                         NaN                        NaN               NaN
# 11                          no                         no                no
# 12                         NaN                        NaN               NaN
# 13                         NaN                        NaN               NaN
# 14                          no                         no                no
# 15                         NaN                        NaN               NaN
# 16                         NaN                        NaN               NaN
# 17                         NaN                        NaN               NaN
# 18                         NaN                        NaN               NaN
# 19                          no                         no                no
# 20                          no                         no                no
# 21                          no                         no                no
# 22                         NaN                        NaN               NaN
# 23                         NaN                        NaN               NaN
# 24                         NaN                        NaN               NaN
# 25                          no                         no                no
# 26                          no                         no                no
# 27                          no                         no                no
# 28                          no                         no                no
# 29                         NaN                        NaN               NaN
# ...                        ...                        ...               ...
# 1006                        no                         no                no
# 1007                        no                         no                no
# 1008                       NaN                        NaN               NaN
# 1009                       NaN                        NaN               NaN
# 1010                       NaN                        NaN               NaN
# 1011                        no                         no               yes
# 1012                       NaN                        NaN               NaN
# 1013                       NaN                        NaN               NaN
# 1014                        no                         no               yes
# 1015                        no                         no                no
# 1016                       NaN                        NaN               NaN
# 1017                       NaN                        NaN               NaN
# 1018                        no                         no                no
# 1019                       NaN                        NaN               NaN
# 1020                        no                         no                no
# 1021                       NaN                        NaN               NaN
# 1022                       NaN                        NaN               NaN
# 1023                       NaN                        NaN               NaN
# 1024                        no                         no                no
# 1025                       NaN                        NaN               NaN
# 1026                        no                         no                no
# 1027                       NaN                        NaN               NaN
# 1028                       NaN                        NaN               NaN
# 1029                        no                         no               yes
# 1030                       NaN                        NaN               NaN
# 1031                        no                         no                no
# 1032                       NaN                        NaN               NaN
# 1033                       NaN                        NaN               NaN
# 1034                       NaN                        NaN               NaN
# 1035                        no                         no                no
#
#      SpatialMovingCamera TemporalSplice FaceManipulations  \
# 0                     no             no                no
# 1                    NaN            NaN               NaN
# 2                    NaN            NaN               NaN
# 3                    NaN            NaN               NaN
# 4                    NaN            NaN               NaN
# 5                    NaN            NaN               NaN
# 6                     no             no                no
# 7                    NaN            NaN               NaN
# 8                     no             no                no
# 9                    NaN            NaN               NaN
# 10                   NaN            NaN               NaN
# 11                    no             no                no
# 12                   NaN            NaN               NaN
# 13                   NaN            NaN               NaN
# 14                    no             no                no
# 15                   NaN            NaN               NaN
# 16                   NaN            NaN               NaN
# 17                   NaN            NaN               NaN
# 18                   NaN            NaN               NaN
# 19                    no             no                no
# 20                    no             no                no
# 21                    no             no                no
# 22                   NaN            NaN               NaN
# 23                   NaN            NaN               NaN
# 24                   NaN            NaN               NaN
# 25                    no             no                no
# 26                    no             no                no
# 27                    no             no                no
# 28                    no             no                no
# 29                   NaN            NaN               NaN
# ...                  ...            ...               ...
# 1006                  no             no                no
# 1007                  no             no                no
# 1008                 NaN            NaN               NaN
# 1009                 NaN            NaN               NaN
# 1010                 NaN            NaN               NaN
# 1011                  no             no                no
# 1012                 NaN            NaN               NaN
# 1013                 NaN            NaN               NaN
# 1014                  no             no                no
# 1015                  no             no                no
# 1016                 NaN            NaN               NaN
# 1017                 NaN            NaN               NaN
# 1018                  no             no                no
# 1019                 NaN            NaN               NaN
# 1020                  no             no                no
# 1021                 NaN            NaN               NaN
# 1022                 NaN            NaN               NaN
# 1023                 NaN            NaN               NaN
# 1024                  no             no                no
# 1025                 NaN            NaN               NaN
# 1026                  no             no                no
# 1027                 NaN            NaN               NaN
# 1028                 NaN            NaN               NaN
# 1029                  no             no                no
# 1030                 NaN            NaN               NaN
# 1031                  no             no                no
# 1032                 NaN            NaN               NaN
# 1033                 NaN            NaN               NaN
# 1034                 NaN            NaN               NaN
# 1035                  no             no                no
#
#      ReflectionManipulations ShadowManipulations
# 0                         no                  no
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
# 5                        NaN                 NaN
# 6                         no                  no
# 7                        NaN                 NaN
# 8                         no                  no
# 9                        NaN                 NaN
# 10                       NaN                 NaN
# 11                        no                  no
# 12                       NaN                 NaN
# 13                       NaN                 NaN
# 14                        no                  no
# 15                       NaN                 NaN
# 16                       NaN                 NaN
# 17                       NaN                 NaN
# 18                       NaN                 NaN
# 19                        no                  no
# 20                        no                  no
# 21                        no                  no
# 22                       NaN                 NaN
# 23                       NaN                 NaN
# 24                       NaN                 NaN
# 25                        no                  no
# 26                        no                  no
# 27                        no                  no
# 28                        no                  no
# 29                       NaN                 NaN
# ...                      ...                 ...
# 1006                      no                  no
# 1007                      no                  no
# 1008                     NaN                 NaN
# 1009                     NaN                 NaN
# 1010                     NaN                 NaN
# 1011                      no                  no
# 1012                     NaN                 NaN
# 1013                     NaN                 NaN
# 1014                      no                  no
# 1015                      no                  no
# 1016                     NaN                 NaN
# 1017                     NaN                 NaN
# 1018                      no                  no
# 1019                     NaN                 NaN
# 1020                      no                  no
# 1021                     NaN                 NaN
# 1022                     NaN                 NaN
# 1023                     NaN                 NaN
# 1024                      no                  no
# 1025                     NaN                 NaN
# 1026                      no                  no
# 1027                     NaN                 NaN
# 1028                     NaN                 NaN
# 1029                      no                  no
# 1030                     NaN                 NaN
# 1031                      no                  no
# 1032                     NaN                 NaN
# 1033                     NaN                 NaN
# 1034                     NaN                 NaN
# 1035                      no                  no
#
# [1036 rows x 60 columns]

# %%
non_target = 'probe/001c934acb38a59cb28b680b79485dcd.mp4' #0
target = 'probe/01d1021c3452df3c3bdcbe950f7e632e.mp4' #6

# %% [markdown]
# python3 extract_cnn_features.py --video_path file.mp4 --cnn_root cnn_folder --cnn_model cnn_name --feature_path file.npy
#
# python ../cnn/validate_cnn.py --video_db_path /nas/home/pbestagini/video_codec_identification_icip/dataset/video_encoded/large/video_db.npy --hdf5_path /nas/home/pbestagini/video_codec_identification_icip/dataset/hdf5/large/mixed.hdf5 --cnn_model cnn_video_codec_seba --cnn_root ../models/cnn_video_codec_seba_selected

# %%
tv_path = os.path.join(dataset_root, target)
ntv_path = os.path.join(dataset_root, non_target)

# %%
tv_ff = extract_features(video_path=tv_path,
                         cnn_root= '../video_codec_cnn/models/cnn_video_codec_seba', 
                         cnn_model= 'cnn_video_codec_seba')

# %%
ntv_ff = extract_features(video_path=ntv_path,
                         cnn_root= '../video_codec_cnn/models/cnn_video_codec_seba', 
                         cnn_model= 'cnn_video_codec_seba')

# %%
tv_ff_p = extract_features(video_path=tv_path,
                         cnn_root= '../video_codec_cnn/models/cnn_video_codec_seba', 
                         cnn_model= 'cnn_video_codec_seba', 
                         per_patch=True)

# %%
ntv_ff_p = extract_features(video_path=ntv_path,
                         cnn_root= '../video_codec_cnn/models/cnn_video_codec_seba', 
                         cnn_model= 'cnn_video_codec_seba', 
                         per_patch=True)

# %%
# tv_ff = np.load('tv_ff.npy')
# ntv_ff = np.load('ntv_ff.npy')

# %%
tv_ff_p.shape
# Out:
# (16, 30, 4, 420)

# %%
# %matplotlib notebook
plt.subplot(1, 2, 1)
plt.imshow(tv_ff, aspect='auto')

plt.subplot(1, 2, 2)
plt.imshow(ntv_ff, aspect='auto')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# %matplotlib inline
for i in range(tv_ff_p.shape[0]):
    for j in range(tv_ff_p.shape[1]):
        plt.imshow(tv_ff_p[i, j], aspect='auto')
        plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-8d5819c2184d> in <module>
#       3     for j in range(tv_ff_p.shape[1]):
#       4         plt.imshow(tv_ff_p[i, j], aspect='auto')
# ----> 5         plt.show()
#       6 plt.tight_layout()
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# /opt/miniconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4394
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#    4398                     (bbox.width != 0 or bbox.height != 0) and
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1138             return
#    1139
# -> 1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
#    1142         self._update_label_position(renderer)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/ticker.py in __call__(self)
#    1983     def __call__(self):
#    1984         vmin, vmax = self.axis.get_view_interval()
# -> 1985         return self.tick_values(vmin, vmax)
#    1986
#    1987     def tick_values(self, vmin, vmax):
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1991         vmin, vmax = mtransforms.nonsingular(
#    1992             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1993         locs = self._raw_ticks(vmin, vmax)
#    1994
#    1995         prune = self._prune
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1930         if self._nbins == 'auto':
#    1931             if self.axis is not None:
# -> 1932                 nbins = np.clip(self.axis.get_tick_space(),
#    1933                                 max(1, self._min_n_ticks - 1), 9)
#    1934             else:
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2537         ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2538         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# -> 2539         tick = self._get_tick(True)
#    2540         # Having a spacing of at least 2 just looks good.
#    2541         size = tick.label1.get_size() * 2.0
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2192         else:
#    2193             tick_kw = self._minor_tick_kw
# -> 2194         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2195
#    2196     def _get_label(self):
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     173
#     174         self.tick1line = self._get_tick1line()
# --> 175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#     177
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     607                           markersize=self._size,
#     608                           markeredgewidth=self._width,
# --> 609                           zorder=self._zorder)
#     610         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     611         self._set_artist_props(l)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     399         self._markerfacecoloralt = None
#     400
# --> 401         self.set_markerfacecolor(markerfacecolor)
#     402         self.set_markerfacecoloralt(markerfacecoloralt)
#     403         self.set_markeredgecolor(markeredgecolor)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/lines.py in set_markerfacecolor(self, fc)
#    1157         if fc is None:
#    1158             fc = 'auto'
# -> 1159         if np.any(self._markerfacecolor != fc):
#    1160             self.stale = True
#    1161         self._markerfacecolor = fc
#
# /opt/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2011
#    2012     """
# -> 2013     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2014
#    2015
#
# KeyboardInterrupt:

# %%
tv_ff_p.shape[0]
# Out:
# 16
